# %% [markdown]
# REST API

# %%
import requests,json
api_key="81c148fded66cf6945b9fe227e878f6e"
city=input("enter city: ")
url="http://api.openweathermap.org/geo/1.0/direct?q="+city+"&appid="+api_key
response=requests.get(url)
result=response.json()
# print(json.dumps(result,indent=3))
print(result)
# Out:
# enter city:  ahmedabad
# [{'name': 'Ahmedabad', 'local_names': {'kn': 'ಅಹ್ಮದಾಬಾದ್', 'mr': 'अहमदाबाद', 'pl': 'Ahmadabad', 'te': 'అహ్మదాబాద్', 'ja': 'アフマダーバード', 'feature_name': 'Ahmedabad', 'he': 'אחמדאבאד', 'ml': 'അഹമ്മദാബാദ്', 'ar': 'أحمد آباد', 'de': 'Ahmedabad', 'or': 'ଅହମଦାବାଦ', 'eo': 'Ahmadabado', 'ta': 'அகமதாபாத்', 'en': 'Ahmedabad', 'ur': 'احمد آباد', 'ne': 'अहमदाबाद', 'tt': 'Әхмәтабад', 'ascii': 'Ahmedabad', 'oc': 'Ahmadabad', 'gu': 'અમદાવાદ', 'pa': 'ਅਹਿਮਦਾਬਾਦ', 'ru': 'Ахмадабад', 'zh': '艾哈迈达巴德', 'bn': 'আহমেদাবাদ', 'hi': 'अहमदाबाद', 'cs': 'Ahmadábád', 'uk': 'Ахмедабад'}, 'lat': 23.0215374, 'lon': 72.5800568, 'country': 'IN', 'state': 'Gujarat'}]

# %%
lat=result[0]["lat"]
print(lat)
lon=result[0]["lon"]
print(lon)
# Out:
# 23.0215374
# 72.5800568

# %%
url1="https://api.openweathermap.org/data/2.5/weather?lat="+str(lat)+"&lon="+str(lon)+"&appid="+api_key+"&units=metric"
response=requests.get(url1)
result=response.json()
# print(json.dumps(result,indent=3))
print("temp=",result["main"]["temp"])
# Out:
# temp= 32.04

# %%
print("wind speed",result["wind"]["speed"])
# Out:
# wind speed 4.63

# %%
print("temp=",result["weather"][0]["description"])
# Out:
# temp= smoke

# %%
url1="http://api.openweathermap.org/data/2.5/air_pollution?lat="+str(lat)+"&lon="+str(lon)+"&appid="+api_key+"&units=metric"
response=requests.get(url1)
result=response.json()
print(json.dumps(result,indent=3))
print("AQI= ",result["list"][0]["main"]["aqi"])
# Out:
# {
#    "coord": {
#       "lon": 72.5801,
#       "lat": 23.0215
#    },
#    "list": [
#       {
#          "main": {
#             "aqi": 2
#          },
#          "components": {
#             "co": 101.91,
#             "no": 0.27,
#             "no2": 1.09,
#             "o3": 54.6,
#             "so2": 1.71,
#             "pm2_5": 8.99,
#             "pm10": 33.35,
#             "nh3": 0.81
#          },
#          "dt": 1779856729
#       }
#    ]
# }
# AQI=  2

# %%
import requests,json
api_key="81c148fded66cf6945b9fe227e878f6e"
temp=[]
dt=[]
w=[]
for i in range(0,6):
    city=input("enter city: ")
    url="http://api.openweathermap.org/geo/1.0/direct?q="+city+"&appid="+api_key
    response=requests.get(url)
    result=response.json()
    #print(json.dumps(result,indent=3))
    print(result)

    url1="https://api.openweathermap.org/data/2.5/weather?lat="+str(lat)+"&lon="+str(lon)+"&appid="+api_key+"&units=metric"
    response=requests.get(url1)
    result=response.json()
    # print(result)
    # temp=result["main"]["temp"]
    # temp1=str(temp)
    # temp.append(temp1)
    # w=result["weather"][0]["description"]
    # w.append(w)
    # dt=result["list"][0]["dt_txt"]
    # dt.append(dt)

import pandas as pd
df=pd.DataFrame({"Date_time":dt,"temp":temp,"Weather":w})
print(df)
# Out:
# enter city:  gujarat
# [{'name': 'GIFT City', 'lat': 23.16290525, 'lon': 72.68869496501037, 'country': 'IN', 'state': 'Gujarat'}]
# enter city:  ahmedabad
# [{'name': 'Ahmedabad', 'local_names': {'zh': '艾哈迈达巴德', 'de': 'Ahmedabad', 'eo': 'Ahmadabado', 'ne': 'अहमदाबाद', 'or': 'ଅହମଦାବାଦ', 'uk': 'Ахмедабад', 'feature_name': 'Ahmedabad', 'he': 'אחמדאבאד', 'ru': 'Ахмадабад', 'pa': 'ਅਹਿਮਦਾਬਾਦ', 'mr': 'अहमदाबाद', 'pl': 'Ahmadabad', 'bn': 'আহমেদাবাদ', 'te': 'అహ్మదాబాద్', 'ta': 'அகமதாபாத்', 'ja': 'アフマダーバード', 'kn': 'ಅಹ್ಮದಾಬಾದ್', 'ar': 'أحمد آباد', 'ur': 'احمد آباد', 'gu': 'અમદાવાદ', 'ml': 'അഹമ്മദാബാദ്', 'tt': 'Әхмәтабад', 'hi': 'अहमदाबाद', 'cs': 'Ahmadábád', 'en': 'Ahmedabad', 'ascii': 'Ahmedabad', 'oc': 'Ahmadabad'}, 'lat': 23.0215374, 'lon': 72.5800568, 'country': 'IN', 'state': 'Gujarat'}]
# enter city:  bhuj
# ...

# %%
url1="https://api.openweathermap.org/data/2.5/weather?lat="+str(lat)+"&lon="+str(lon)+"&appid="+api_key+"&units=metric"
response=requests.get(url1)
result=response.json()
print(result)
# Out:
# {'coord': {'lon': 72.6887, 'lat': 23.1629}, 'weather': [{'id': 711, 'main': 'Smoke', 'description': 'smoke', 'icon': '50d'}, {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 30.93, 'feels_like': 33.53, 'temp_min': 30.93, 'temp_max': 30.93, 'pressure': 1010, 'humidity': 55, 'sea_level': 1010, 'grnd_level': 1002}, 'visibility': 4000, 'wind': {'speed': 4.12, 'deg': 230}, 'clouds': {'all': 0}, 'dt': 1779854772, 'sys': {'type': 1, 'id': 9049, 'country': 'IN', 'sunrise': 1779841457, 'sunset': 1779889726}, 'timezone': 19800, 'id': 1271715, 'name': 'Gandhinagar', 'cod': 200}

# %%
#Json PlaceHolder
import requests,json
url="https://jsonplaceholder.typicode.com/posts/1"
response=requests.get(url)
print(response)
print(response.status_code)
print(response.text)

data=response.json()
print(type(data))

print(data["userId"])
print(data["title"])
print("---"*50)

print("pretty print json")

print(json.dumps(data,indent=4))
# Out:
# <Response [200]>
# 200
# {
#   "userId": 1,
#   "id": 1,
#   "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#   "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }
# <class 'dict'>
# 1
# sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# pretty print json
# {
#     "userId": 1,
#     "id": 1,
#     "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#     "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }

# %%
url="https://jsonplaceholder.typicode.com/posts"
r=requests.get(url)
data=r.json()
for i in data[:5]:
    print(i["id"],i["title"])
# Out:
# 1 sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# 2 qui est esse
# 3 ea molestias quasi exercitationem repellat qui ipsa sit aut
# 4 eum et est occaecati
# 5 nesciunt quas odio

# %%
#Send Query

params={"userId":1}
r=requests.get("https://jsonplaceholder.typicode.com/posts",params=params)
print(r.url)

f_p=r.json()
print(f_p)
# Out:
# https://jsonplaceholder.typicode.com/posts?userId=1
# ...

# %%
# Send custom headers
headers = {
"User-Agent": "Mozilla/5.0",
"Accept": "application/json"
}
response = requests.get(
"https://jsonplaceholder.typicode.com/posts/1",
headers=headers
)
print(headers)
print(response.status_code)
# Out:
# {'User-Agent': 'Mozilla/5.0', 'Accept': 'application/json'}
# 200

# %%
# Send POST request
new_post = {
"title": "Learning Requests",
"body": "This is tutorial content",
"userId": 1
}
response = requests.post(
"https://jsonplaceholder.typicode.com/posts",
json=new_post
)
print(response.status_code)
print(response.json())
# Out:
# 201
# {'title': 'Learning Requests', 'body': 'This is tutorial content', 'userId': 1, 'id': 101}

# %%
# Send PUT request
updated_post = {
"id": 1,
"title": "Updated Title",
"body": "Updated body",
"userId": 1
}
response = requests.put(
"https://jsonplaceholder.typicode.com/posts/1",
json=updated_post
)
print(response.json())
# Out:
# {'id': 1, 'title': 'Updated Title', 'body': 'Updated body', 'userId': 1}

# %%
patch_data = {
"title": "Patched Title"
}
response = requests.patch(
"https://jsonplaceholder.typicode.com/posts/1",
json=patch_data
)

# %%
# Send DELETE request
response = requests.delete(
"https://jsonplaceholder.typicode.com/posts/1"
)
print(response.status_code)
# View response headers
response = requests.get(
"https://jsonplaceholder.typicode.com/posts/1"
)
print(response.headers)
# Out:
# 200
# ...
